# %% [markdown]
# <a href="https://colab.research.google.com/github/DajanaKolarova/AI_TB_model/blob/main/TB_ResNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import numpy as np
from pathlib import Path
import cv2
import math
from sklearn.metrics import recall_score, accuracy_score, confusion_matrix, ConfusionMatrixDisplay, classification_report
from collections.abc import Iterable
import matplotlib.pyplot as plt
import timm
import torchvision

# %%
batch_size=30
img_size=224

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
target_class={0:"Normal",1:"Tuberculosis"}
Normal_dir=Path("/content/drive/MyDrive/TB_xray_original_dataset/Normal")
TB_dir=Path("/content/drive/MyDrive/TB_xray_original_dataset/Tuberculosis")

# %%
Normal_images:list=sorted(list(map(str, list(Normal_dir.glob("*.png")))))
TB_images:list=sorted(list(map(str, list(TB_dir.glob("*.png")))))
Normal_labels:list=[0]*len(Normal_images)
TB_labels:list=[1]*len(TB_images)

# %%
images=np.array(Normal_images+TB_images)
labels=np.array(Normal_labels+TB_labels)
images.shape, labels.shape
# Out:
# ((1400,), (1400,))

# %%
from sklearn.model_selection import train_test_split
x_train, x_valid, y_train, y_valid = train_test_split(images,labels,test_size=0.2,random_state=42)
x_valid,x_test,y_valid,y_test=train_test_split(x_valid,y_valid,test_size=0.5,random_state=42)
(x_train.shape,x_valid.shape,x_test.shape)
# Out:
# ((1120,), (140,), (140,))

# %%
def image_preprocessing(path):
    img=cv2.imread(path)
    img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    clahe=cv2.createCLAHE(clipLimit=2)
    img=clahe.apply(img)
    img=cv2.GaussianBlur(img,(5,5),0,borderType=cv2.BORDER_CONSTANT)
    img=cv2.resize(img,(img_size,img_size),interpolation=cv2.INTER_LINEAR)
    img=cv2.cvtColor(img,cv2.COLOR_GRAY2RGB)
    img=np.moveaxis(img,-1,0)
    return img

# %%
x_train=np.array(list(map(image_preprocessing,x_train))).astype(np.float32)
x_valid=np.array(list(map(image_preprocessing,x_valid))).astype(np.float32)
x_test=np.array(list(map(image_preprocessing,x_test))).astype(np.float32)
x_train.shape,x_valid.shape,x_test.shape
# Out:
# ((1120, 3, 224, 224), (140, 3, 224, 224), (140, 3, 224, 224))

# %%
device=("cuda" if torch.cuda.is_available() else "cpu")
x_train=torch.from_numpy(x_train).to(device)
x_valid=torch.from_numpy(x_valid).to(device)
x_test=torch.from_numpy(x_test).to(device)
y_train=torch.from_numpy(y_train).to(device)
y_valid=torch.from_numpy(y_valid).to(device)
y_test=torch.from_numpy(y_test).to(device)

# %%
class StandardScaler():
    def __init__(self) -> None:
        self.mean=None
        self.std=None
    def fit(self,tensor:torch.Tensor) -> None:
        self.mean=tensor.mean((0,2,3),keepdim=True)
        self.std=tensor.std((0,2,3),keepdim=True)
    def transform(self,tensor:torch.Tensor) -> torch.Tensor:
        scaled=(tensor-self.mean)/(self.std+1e-5)
        return scaled
    def fit_transform(self,tensor:torch.Tensor) -> torch.Tensor:
        self.fit(tensor=tensor)
        scaled=self.transform(tensor=tensor)
        return scaled

# %%
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)
x_valid=scaler.transform(x_valid)

# %%
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader

# %%
train_dataset=TensorDataset(x_train,y_train)
val_dataset=TensorDataset(x_valid,y_valid)
test_dataset=TensorDataset(x_test,y_test)
train_loader=DataLoader(train_dataset,batch_size=batch_size,shuffle=False)
val_loader=DataLoader(val_dataset,batch_size=batch_size,shuffle=False)
test_loader=DataLoader(test_dataset,batch_size=batch_size,shuffle=False)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, random_split
from torchvision import transforms, models
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
#from medmnist import INFO, Evaluator
#from medmnist.dataset import BloodMNIST
import numpy as np
import copy
from torchvision.models import resnet18

# %% [markdown]
# torch: Core library for building and managing deep learning models.
#
# torch.nn: Provides modules for creating and defining layers in neural networks.
#
# Contains functions for operations like activation functions (F.relu) and loss functions (F.cross_entropy).
#
# torch.optim: Includes optimizers like SGD (Stochastic Gradient Descent), Adam, etc., for training models.
#
# DataLoader: Used to load data in batches for efficient training.
#
# random_split: Splits datasets into training, validation, or test sets.
#
# transforms:
# Used for preprocessing and augmenting image datasets.
#
# matplotlib.pyplot:
# Used for visualizing data and plotting metrics
#
# Generates a detailed report with precision, recall, F1-score, and support for each class.
#
# numpy:
# A fundamental library for numerical computations and matrix operations.

# %% [markdown]
# (1) imports the ResNet-18 model from torchvision.models. ResNet-18 is a popular deep convolutional neural network architecture that includes 18 layers and is known for its residual connections, which help mitigate the vanishing gradient problem.
#
# (3) loads the model with pre-trained weights on the ImageNet dataset. These weights provide a strong starting point because the model has already learned to extract general image features (e.g., edges, textures, patterns).
# You can fine-tune this model on your specific dataset instead of training from scratch, which is faster and requires fewer data.
#
# (4) This retrieves the number of input features for the fully connected layer (512 for ResNet-18).
# nn.Linear(model.fc.in_features, num_classes):
# Replaces the original fully connected layer with a new one that outputs predictions for num_classes (your custom number of classes).
# This is necessary to adapt the pre-trained ResNet model for your specific classification problem.
#
# By replacing the fully connected layer, you ensure the model outputs predictions matching your dataset's class count.

# %%
# Set seed for reproducibility
def set_seed(seed=42):
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    np.random.seed(seed)

set_seed(42)

# %% [markdown]
# Reproducibility ensures that the results of a machine learning experiment are consistent when the code is run multiple times.
#
# A random seed is an initialization value that allows random number generators to produce the same sequence of numbers each time the program is run.
# By setting a seed, you make experiments deterministic, which is especially important in machine learning to debug and compare results.

# %%
# Check for GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# Data loading and transformation
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

# %% [markdown]
# defines the data transformations that will be applied to the input dataset before it is fed into the model. These transformations are crucial for data preprocessing and augmentation, ensuring that the input data is in the correct format and normalized for better model training.
#
# Automatically scales the pixel values from the range [0, 255] to the range [0, 1] by dividing each value by 255.
# Why?
#
# PyTorch models work with tensor inputs, so raw images must be converted to tensors.
# Scaling the pixel values ensures that the data is normalized for numerical stability during training.
#
# Why Normalize?
# Standardization:
# Normalizing pixel values ensures that all features (pixel intensities) have the same scale.
# Prevents features with larger values from dominating others during training.
# Improved Convergence:
# Helps the optimizer converge faster by stabilizing gradients.
# Consistent Input Distribution:
# Many pre-trained models assume inputs are normalized to specific ranges (e.g., [-1, 1] or mean=0 and std=1).

# %% [markdown]
# Prints essential metadata about the dataset
#
# Visualizes a random subset of images from the training dataset to understand what the data looks like.
#
# Selects num_samples random images using np.random.choice
#
# Converts the tensor format (Channels x Height x Width) to NumPy format (Height x Width x Channels) using np.rollaxis
#
# Plots the images using matplotlib with their corresponding labels
#
# Counts the number of samples per class in the training dataset
#
# Initializes a zero array class_counts to store class-wise counts.
# Iterates through all the samples in train_data and adds 1 to the respective class index (from the one-hot encoded label)
#
# Bar Plot:
# Plots the counts of samples for each class as a bar chart.
# Helps identify imbalances in the dataset, e.g., if certain classes have significantly fewer samples
#
# NOTE: updated the code to include normalization so the images are not cropped and displayed correctly

# %% [markdown]
# SimpleCNN inherits from torch.nn.Module, which is the base class for all neural network models in PyTorch.
#
# The __init__ method initializes the layers of the network.
#
# num_classes=2 is the number of output classes for classification. You have updated this to num_classes=8 in your instantiation.
#
# Convolutional Layers
#
# conv1: A 2D convolutional layer with 3 input channels (RGB images), 32 output channels, a kernel size of 3x3, and a stride of 1.
# conv2: Another 2D convolutional layer, taking the 32-channel output of conv1 as input and producing 64 output channels.
# These layers learn spatial features from the input images.
#
# Fully Connected (Dense) Layers
#
# fc1: A fully connected layer that takes a flattened input of size 12*12*64 (12x12 is the output size after the convolutions and pooling, and 64 is the number of channels from conv2) and outputs 128 features.
# fc2: The final fully connected layer maps the 128 features to num_classes outputs.
#
# Forward Pass
#
# torch.relu: Applies the Rectified Linear Unit (ReLU) activation function to introduce non-linearity.
# max_pool2d: Applies max pooling with a kernel size of 2, reducing the spatial dimensions by half.
# torch.flatten: Flattens the tensor, making it suitable for fully connected layers. The dim=1 argument preserves the batch dimension.

# %%
# Load a pre-trained ResNet model
model = models.resnet18(weights="DEFAULT")

# Modify the final layer to fit the number of classes
num_classes = 2
model.fc = torch.nn.Linear(model.fc.in_features, num_classes)

# Model summary
print(model)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 207MB/s]
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=2, bias=True)
# )

# %%
model = model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

# Training loop with tracking of losses
num_epochs = 2000
train_losses = []
val_losses = []

for epoch in range(num_epochs):
    # Training phase
    model.train()
    running_train_loss = 0.0
    for images, labels in train_loader:
        labels = labels.view(-1)  # Flatten to [batch_size]
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        output = model(images)
        loss = criterion(output, labels)
        loss.backward()
        optimizer.step()
        running_train_loss += loss.item()

    # Validation phase
    model.eval()
    running_val_loss = 0.0
    with torch.no_grad():
        for images, labels in val_loader:
            labels = labels.view(-1)  # Flatten to [batch_size]
            images, labels = images.to(device), labels.squeeze().to(device)
            output = model(images)
            loss = criterion(output, labels)
            running_val_loss += loss.item()

    # Average losses for the epoch
    epoch_train_loss = running_train_loss / len(train_loader)
    epoch_val_loss = running_val_loss / len(val_loader)

    train_losses.append(epoch_train_loss)
    val_losses.append(epoch_val_loss)

    print(f"Epoch {epoch+1}/{num_epochs}, Training Loss: {epoch_train_loss:.4f}, Validation Loss: {epoch_val_loss:.4f}")

# Plot training and validation losses
plt.plot(range(1, num_epochs+1), train_losses, label='Training Loss')
plt.plot(range(1, num_epochs+1), val_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Losses')
plt.legend()
plt.show()

# Save the model
torch.save(model.state_dict(), "TB_resnet.pth")
print("Model saved to TB_resnet.pth")
# Out:
# Epoch 1/2000, Training Loss: 0.0056, Validation Loss: 0.0272
# Epoch 2/2000, Training Loss: 0.0044, Validation Loss: 0.0245
# Epoch 3/2000, Training Loss: 0.0035, Validation Loss: 0.0225
# Epoch 4/2000, Training Loss: 0.0030, Validation Loss: 0.0210
# Epoch 5/2000, Training Loss: 0.0025, Validation Loss: 0.0197
# Epoch 6/2000, Training Loss: 0.0022, Validation Loss: 0.0188
# Epoch 7/2000, Training Loss: 0.0020, Validation Loss: 0.0180
# Epoch 8/2000, Training Loss: 0.0018, Validation Loss: 0.0172
# Epoch 9/2000, Training Loss: 0.0016, Validation Loss: 0.0166
# Epoch 10/2000, Training Loss: 0.0014, Validation Loss: 0.0160
# Epoch 11/2000, Training Loss: 0.0013, Validation Loss: 0.0155
# Epoch 12/2000, Training Loss: 0.0012, Validation Loss: 0.0151
# Epoch 13/2000, Training Loss: 0.0011, Validation Loss: 0.0147
# Epoch 14/2000, Training Loss: 0.0011, Validation Loss: 0.0143
# Epoch 15/2000, Training Loss: 0.0010, Validation Loss: 0.0140
# Epoch 16/2000, Training Loss: 0.0009, Validation Loss: 0.0137
# Epoch 17/2000, Training Loss: 0.0009, Validation Loss: 0.0134
# Epoch 18/2000, Training Loss: 0.0008, Validation Loss: 0.0131
# Epoch 19/2000, Training Loss: 0.0008, Validation Loss: 0.0128
# Epoch 20/2000, Training Loss: 0.0007, Validation Loss: 0.0126
# Epoch 21/2000, Training Loss: 0.0007, Validation Loss: 0.0124
# Epoch 22/2000, Training Loss: 0.0007, Validation Loss: 0.0122
# Epoch 23/2000, Training Loss: 0.0006, Validation Loss: 0.0120
# Epoch 24/2000, Training Loss: 0.0006, Validation Loss: 0.0117
# Epoch 25/2000, Training Loss: 0.0006, Validation Loss: 0.0116
# Epoch 26/2000, Training Loss: 0.0006, Validation Loss: 0.0114
# Epoch 27/2000, Training Loss: 0.0005, Validation Loss: 0.0112
# Epoch 28/2000, Training Loss: 0.0005, Validation Loss: 0.0111
# Epoch 29/2000, Training Loss: 0.0005, Validation Loss: 0.0109
# Epoch 30/2000, Training Loss: 0.0005, Validation Loss: 0.0108
# Epoch 31/2000, Training Loss: 0.0005, Validation Loss: 0.0106
# Epoch 32/2000, Training Loss: 0.0005, Validation Loss: 0.0105
# Epoch 33/2000, Training Loss: 0.0004, Validation Loss: 0.0104
# Epoch 34/2000, Training Loss: 0.0004, Validation Loss: 0.0103
# Epoch 35/2000, Training Loss: 0.0004, Validation Loss: 0.0101
# Epoch 36/2000, Training Loss: 0.0004, Validation Loss: 0.0100
# Epoch 37/2000, Training Loss: 0.0004, Validation Loss: 0.0099
# Epoch 38/2000, Training Loss: 0.0004, Validation Loss: 0.0098
# Epoch 39/2000, Training Loss: 0.0004, Validation Loss: 0.0097
# Epoch 40/2000, Training Loss: 0.0004, Validation Loss: 0.0096
# Epoch 41/2000, Training Loss: 0.0003, Validation Loss: 0.0095
# Epoch 42/2000, Training Loss: 0.0003, Validation Loss: 0.0094
# Epoch 43/2000, Training Loss: 0.0003, Validation Loss: 0.0093
# Epoch 44/2000, Training Loss: 0.0003, Validation Loss: 0.0092
# Epoch 45/2000, Training Loss: 0.0003, Validation Loss: 0.0092
# Epoch 46/2000, Training Loss: 0.0003, Validation Loss: 0.0091
# Epoch 47/2000, Training Loss: 0.0003, Validation Loss: 0.0090
# Epoch 48/2000, Training Loss: 0.0003, Validation Loss: 0.0089
# Epoch 49/2000, Training Loss: 0.0003, Validation Loss: 0.0089
# Epoch 50/2000, Training Loss: 0.0003, Validation Loss: 0.0088
# Epoch 51/2000, Training Loss: 0.0003, Validation Loss: 0.0087
# Epoch 52/2000, Training Loss: 0.0003, Validation Loss: 0.0086
# Epoch 53/2000, Training Loss: 0.0003, Validation Loss: 0.0086
# Epoch 54/2000, Training Loss: 0.0003, Validation Loss: 0.0085
# Epoch 55/2000, Training Loss: 0.0003, Validation Loss: 0.0084
# Epoch 56/2000, Training Loss: 0.0002, Validation Loss: 0.0084
# Epoch 57/2000, Training Loss: 0.0002, Validation Loss: 0.0083
# Epoch 58/2000, Training Loss: 0.0002, Validation Loss: 0.0082
# Epoch 59/2000, Training Loss: 0.0002, Validation Loss: 0.0082
# Epoch 60/2000, Training Loss: 0.0002, Validation Loss: 0.0081
# Epoch 61/2000, Training Loss: 0.0002, Validation Loss: 0.0081
# Epoch 62/2000, Training Loss: 0.0002, Validation Loss: 0.0080
# Epoch 63/2000, Training Loss: 0.0002, Validation Loss: 0.0079
# Epoch 64/2000, Training Loss: 0.0002, Validation Loss: 0.0079
# Epoch 65/2000, Training Loss: 0.0002, Validation Loss: 0.0078
# Epoch 66/2000, Training Loss: 0.0002, Validation Loss: 0.0078
# Epoch 67/2000, Training Loss: 0.0002, Validation Loss: 0.0077
# Epoch 68/2000, Training Loss: 0.0002, Validation Loss: 0.0077
# Epoch 69/2000, Training Loss: 0.0002, Validation Loss: 0.0076
# Epoch 70/2000, Training Loss: 0.0002, Validation Loss: 0.0076
# Epoch 71/2000, Training Loss: 0.0002, Validation Loss: 0.0075
# Epoch 72/2000, Training Loss: 0.0002, Validation Loss: 0.0075
# Epoch 73/2000, Training Loss: 0.0002, Validation Loss: 0.0074
# Epoch 74/2000, Training Loss: 0.0002, Validation Loss: 0.0074
# Epoch 75/2000, Training Loss: 0.0002, Validation Loss: 0.0074
# Epoch 76/2000, Training Loss: 0.0002, Validation Loss: 0.0073
# Epoch 77/2000, Training Loss: 0.0002, Validation Loss: 0.0073
# Epoch 78/2000, Training Loss: 0.0002, Validation Loss: 0.0072
# Epoch 79/2000, Training Loss: 0.0002, Validation Loss: 0.0072
# Epoch 80/2000, Training Loss: 0.0002, Validation Loss: 0.0072
# Epoch 81/2000, Training Loss: 0.0002, Validation Loss: 0.0071
# Epoch 82/2000, Training Loss: 0.0002, Validation Loss: 0.0071
# Epoch 83/2000, Training Loss: 0.0002, Validation Loss: 0.0070
# Epoch 84/2000, Training Loss: 0.0002, Validation Loss: 0.0070
# Epoch 85/2000, Training Loss: 0.0002, Validation Loss: 0.0070
# Epoch 86/2000, Training Loss: 0.0002, Validation Loss: 0.0069
# Epoch 87/2000, Training Loss: 0.0002, Validation Loss: 0.0069
# Epoch 88/2000, Training Loss: 0.0002, Validation Loss: 0.0069
# Epoch 89/2000, Training Loss: 0.0001, Validation Loss: 0.0068
# Epoch 90/2000, Training Loss: 0.0001, Validation Loss: 0.0068
# Epoch 91/2000, Training Loss: 0.0001, Validation Loss: 0.0068
# Epoch 92/2000, Training Loss: 0.0001, Validation Loss: 0.0067
# Epoch 93/2000, Training Loss: 0.0001, Validation Loss: 0.0067
# Epoch 94/2000, Training Loss: 0.0001, Validation Loss: 0.0067
# Epoch 95/2000, Training Loss: 0.0001, Validation Loss: 0.0066
# Epoch 96/2000, Training Loss: 0.0001, Validation Loss: 0.0066
# Epoch 97/2000, Training Loss: 0.0001, Validation Loss: 0.0066
# Epoch 98/2000, Training Loss: 0.0001, Validation Loss: 0.0065
# Epoch 99/2000, Training Loss: 0.0001, Validation Loss: 0.0065
# Epoch 100/2000, Training Loss: 0.0001, Validation Loss: 0.0065
# Epoch 101/2000, Training Loss: 0.0001, Validation Loss: 0.0065
# Epoch 102/2000, Training Loss: 0.0001, Validation Loss: 0.0064
# Epoch 103/2000, Training Loss: 0.0001, Validation Loss: 0.0064
# Epoch 104/2000, Training Loss: 0.0001, Validation Loss: 0.0064
# Epoch 105/2000, Training Loss: 0.0001, Validation Loss: 0.0063
# Epoch 106/2000, Training Loss: 0.0001, Validation Loss: 0.0063
# Epoch 107/2000, Training Loss: 0.0001, Validation Loss: 0.0063
# Epoch 108/2000, Training Loss: 0.0001, Validation Loss: 0.0063
# Epoch 109/2000, Training Loss: 0.0001, Validation Loss: 0.0062
# Epoch 110/2000, Training Loss: 0.0001, Validation Loss: 0.0062
# Epoch 111/2000, Training Loss: 0.0001, Validation Loss: 0.0062
# Epoch 112/2000, Training Loss: 0.0001, Validation Loss: 0.0062
# Epoch 113/2000, Training Loss: 0.0001, Validation Loss: 0.0061
# Epoch 114/2000, Training Loss: 0.0001, Validation Loss: 0.0061
# Epoch 115/2000, Training Loss: 0.0001, Validation Loss: 0.0061
# Epoch 116/2000, Training Loss: 0.0001, Validation Loss: 0.0061
# Epoch 117/2000, Training Loss: 0.0001, Validation Loss: 0.0060
# Epoch 118/2000, Training Loss: 0.0001, Validation Loss: 0.0060
# Epoch 119/2000, Training Loss: 0.0001, Validation Loss: 0.0060
# Epoch 120/2000, Training Loss: 0.0001, Validation Loss: 0.0060
# Epoch 121/2000, Training Loss: 0.0001, Validation Loss: 0.0060
# Epoch 122/2000, Training Loss: 0.0001, Validation Loss: 0.0059
# Epoch 123/2000, Training Loss: 0.0001, Validation Loss: 0.0059
# Epoch 124/2000, Training Loss: 0.0001, Validation Loss: 0.0059
# Epoch 125/2000, Training Loss: 0.0001, Validation Loss: 0.0059
# Epoch 126/2000, Training Loss: 0.0001, Validation Loss: 0.0058
# Epoch 127/2000, Training Loss: 0.0001, Validation Loss: 0.0058
# Epoch 128/2000, Training Loss: 0.0001, Validation Loss: 0.0058
# Epoch 129/2000, Training Loss: 0.0001, Validation Loss: 0.0058
# Epoch 130/2000, Training Loss: 0.0001, Validation Loss: 0.0058
# Epoch 131/2000, Training Loss: 0.0001, Validation Loss: 0.0057
# Epoch 132/2000, Training Loss: 0.0001, Validation Loss: 0.0057
# Epoch 133/2000, Training Loss: 0.0001, Validation Loss: 0.0057
# Epoch 134/2000, Training Loss: 0.0001, Validation Loss: 0.0057
# Epoch 135/2000, Training Loss: 0.0001, Validation Loss: 0.0057
# Epoch 136/2000, Training Loss: 0.0001, Validation Loss: 0.0056
# Epoch 137/2000, Training Loss: 0.0001, Validation Loss: 0.0056
# Epoch 138/2000, Training Loss: 0.0001, Validation Loss: 0.0056
# Epoch 139/2000, Training Loss: 0.0001, Validation Loss: 0.0056
# Epoch 140/2000, Training Loss: 0.0001, Validation Loss: 0.0056
# Epoch 141/2000, Training Loss: 0.0001, Validation Loss: 0.0056
# Epoch 142/2000, Training Loss: 0.0001, Validation Loss: 0.0055
# Epoch 143/2000, Training Loss: 0.0001, Validation Loss: 0.0055
# Epoch 144/2000, Training Loss: 0.0001, Validation Loss: 0.0055
# Epoch 145/2000, Training Loss: 0.0001, Validation Loss: 0.0055
# Epoch 146/2000, Training Loss: 0.0001, Validation Loss: 0.0055
# Epoch 147/2000, Training Loss: 0.0001, Validation Loss: 0.0055
# Epoch 148/2000, Training Loss: 0.0001, Validation Loss: 0.0054
# Epoch 149/2000, Training Loss: 0.0001, Validation Loss: 0.0054
# Epoch 150/2000, Training Loss: 0.0001, Validation Loss: 0.0054
# Epoch 151/2000, Training Loss: 0.0001, Validation Loss: 0.0054
# Epoch 152/2000, Training Loss: 0.0001, Validation Loss: 0.0054
# Epoch 153/2000, Training Loss: 0.0001, Validation Loss: 0.0054
# Epoch 154/2000, Training Loss: 0.0001, Validation Loss: 0.0053
# Epoch 155/2000, Training Loss: 0.0001, Validation Loss: 0.0053
# Epoch 156/2000, Training Loss: 0.0001, Validation Loss: 0.0053
# Epoch 157/2000, Training Loss: 0.0001, Validation Loss: 0.0053
# Epoch 158/2000, Training Loss: 0.0001, Validation Loss: 0.0053
# Epoch 159/2000, Training Loss: 0.0001, Validation Loss: 0.0053
# Epoch 160/2000, Training Loss: 0.0001, Validation Loss: 0.0053
# Epoch 161/2000, Training Loss: 0.0001, Validation Loss: 0.0052
# Epoch 162/2000, Training Loss: 0.0001, Validation Loss: 0.0052
# Epoch 163/2000, Training Loss: 0.0001, Validation Loss: 0.0052
# Epoch 164/2000, Training Loss: 0.0001, Validation Loss: 0.0052
# Epoch 165/2000, Training Loss: 0.0001, Validation Loss: 0.0052
# Epoch 166/2000, Training Loss: 0.0001, Validation Loss: 0.0052
# Epoch 167/2000, Training Loss: 0.0001, Validation Loss: 0.0052
# Epoch 168/2000, Training Loss: 0.0001, Validation Loss: 0.0051
# Epoch 169/2000, Training Loss: 0.0001, Validation Loss: 0.0051
# Epoch 170/2000, Training Loss: 0.0001, Validation Loss: 0.0051
# Epoch 171/2000, Training Loss: 0.0001, Validation Loss: 0.0051
# Epoch 172/2000, Training Loss: 0.0001, Validation Loss: 0.0051
# Epoch 173/2000, Training Loss: 0.0001, Validation Loss: 0.0051
# Epoch 174/2000, Training Loss: 0.0001, Validation Loss: 0.0051
# Epoch 175/2000, Training Loss: 0.0001, Validation Loss: 0.0050
# Epoch 176/2000, Training Loss: 0.0001, Validation Loss: 0.0050
# Epoch 177/2000, Training Loss: 0.0001, Validation Loss: 0.0050
# Epoch 178/2000, Training Loss: 0.0001, Validation Loss: 0.0050
# Epoch 179/2000, Training Loss: 0.0001, Validation Loss: 0.0050
# Epoch 180/2000, Training Loss: 0.0001, Validation Loss: 0.0050
# Epoch 181/2000, Training Loss: 0.0001, Validation Loss: 0.0050
# Epoch 182/2000, Training Loss: 0.0001, Validation Loss: 0.0050
# Epoch 183/2000, Training Loss: 0.0001, Validation Loss: 0.0049
# Epoch 184/2000, Training Loss: 0.0001, Validation Loss: 0.0049
# Epoch 185/2000, Training Loss: 0.0001, Validation Loss: 0.0049
# Epoch 186/2000, Training Loss: 0.0001, Validation Loss: 0.0049
# Epoch 187/2000, Training Loss: 0.0001, Validation Loss: 0.0049
# Epoch 188/2000, Training Loss: 0.0001, Validation Loss: 0.0049
# Epoch 189/2000, Training Loss: 0.0001, Validation Loss: 0.0049
# Epoch 190/2000, Training Loss: 0.0001, Validation Loss: 0.0049
# Epoch 191/2000, Training Loss: 0.0001, Validation Loss: 0.0048
# Epoch 192/2000, Training Loss: 0.0001, Validation Loss: 0.0048
# Epoch 193/2000, Training Loss: 0.0001, Validation Loss: 0.0048
# Epoch 194/2000, Training Loss: 0.0001, Validation Loss: 0.0048
# Epoch 195/2000, Training Loss: 0.0001, Validation Loss: 0.0048
# Epoch 196/2000, Training Loss: 0.0001, Validation Loss: 0.0048
# Epoch 197/2000, Training Loss: 0.0001, Validation Loss: 0.0048
# Epoch 198/2000, Training Loss: 0.0001, Validation Loss: 0.0048
# Epoch 199/2000, Training Loss: 0.0001, Validation Loss: 0.0048
# Epoch 200/2000, Training Loss: 0.0001, Validation Loss: 0.0048
# Epoch 201/2000, Training Loss: 0.0001, Validation Loss: 0.0047
# Epoch 202/2000, Training Loss: 0.0001, Validation Loss: 0.0047
# Epoch 203/2000, Training Loss: 0.0001, Validation Loss: 0.0047
# Epoch 204/2000, Training Loss: 0.0001, Validation Loss: 0.0047
# Epoch 205/2000, Training Loss: 0.0001, Validation Loss: 0.0047
# Epoch 206/2000, Training Loss: 0.0001, Validation Loss: 0.0047
# Epoch 207/2000, Training Loss: 0.0001, Validation Loss: 0.0047
# Epoch 208/2000, Training Loss: 0.0001, Validation Loss: 0.0047
# Epoch 209/2000, Training Loss: 0.0001, Validation Loss: 0.0047
# Epoch 210/2000, Training Loss: 0.0001, Validation Loss: 0.0046
# Epoch 211/2000, Training Loss: 0.0001, Validation Loss: 0.0046
# Epoch 212/2000, Training Loss: 0.0001, Validation Loss: 0.0046
# Epoch 213/2000, Training Loss: 0.0001, Validation Loss: 0.0046
# Epoch 214/2000, Training Loss: 0.0001, Validation Loss: 0.0046
# Epoch 215/2000, Training Loss: 0.0001, Validation Loss: 0.0046
# Epoch 216/2000, Training Loss: 0.0001, Validation Loss: 0.0046
# Epoch 217/2000, Training Loss: 0.0001, Validation Loss: 0.0046
# Epoch 218/2000, Training Loss: 0.0001, Validation Loss: 0.0046
# Epoch 219/2000, Training Loss: 0.0001, Validation Loss: 0.0046
# Epoch 220/2000, Training Loss: 0.0001, Validation Loss: 0.0045
# Epoch 221/2000, Training Loss: 0.0001, Validation Loss: 0.0045
# Epoch 222/2000, Training Loss: 0.0001, Validation Loss: 0.0045
# Epoch 223/2000, Training Loss: 0.0001, Validation Loss: 0.0045
# Epoch 224/2000, Training Loss: 0.0001, Validation Loss: 0.0045
# Epoch 225/2000, Training Loss: 0.0001, Validation Loss: 0.0045
# Epoch 226/2000, Training Loss: 0.0001, Validation Loss: 0.0045
# Epoch 227/2000, Training Loss: 0.0001, Validation Loss: 0.0045
# Epoch 228/2000, Training Loss: 0.0001, Validation Loss: 0.0045
# Epoch 229/2000, Training Loss: 0.0001, Validation Loss: 0.0045
# Epoch 230/2000, Training Loss: 0.0001, Validation Loss: 0.0045
# Epoch 231/2000, Training Loss: 0.0001, Validation Loss: 0.0044
# Epoch 232/2000, Training Loss: 0.0001, Validation Loss: 0.0044
# Epoch 233/2000, Training Loss: 0.0001, Validation Loss: 0.0044
# Epoch 234/2000, Training Loss: 0.0001, Validation Loss: 0.0044
# Epoch 235/2000, Training Loss: 0.0001, Validation Loss: 0.0044
# Epoch 236/2000, Training Loss: 0.0001, Validation Loss: 0.0044
# Epoch 237/2000, Training Loss: 0.0001, Validation Loss: 0.0044
# Epoch 238/2000, Training Loss: 0.0001, Validation Loss: 0.0044
# Epoch 239/2000, Training Loss: 0.0001, Validation Loss: 0.0044
# Epoch 240/2000, Training Loss: 0.0001, Validation Loss: 0.0044
# Epoch 241/2000, Training Loss: 0.0000, Validation Loss: 0.0044
# Epoch 242/2000, Training Loss: 0.0000, Validation Loss: 0.0043
# Epoch 243/2000, Training Loss: 0.0000, Validation Loss: 0.0043
# Epoch 244/2000, Training Loss: 0.0000, Validation Loss: 0.0043
# Epoch 245/2000, Training Loss: 0.0000, Validation Loss: 0.0043
# Epoch 246/2000, Training Loss: 0.0000, Validation Loss: 0.0043
# Epoch 247/2000, Training Loss: 0.0000, Validation Loss: 0.0043
# Epoch 248/2000, Training Loss: 0.0000, Validation Loss: 0.0043
# Epoch 249/2000, Training Loss: 0.0000, Validation Loss: 0.0043
# Epoch 250/2000, Training Loss: 0.0000, Validation Loss: 0.0043
# Epoch 251/2000, Training Loss: 0.0000, Validation Loss: 0.0043
# Epoch 252/2000, Training Loss: 0.0000, Validation Loss: 0.0043
# Epoch 253/2000, Training Loss: 0.0000, Validation Loss: 0.0043
# Epoch 254/2000, Training Loss: 0.0000, Validation Loss: 0.0043
# Epoch 255/2000, Training Loss: 0.0000, Validation Loss: 0.0042
# Epoch 256/2000, Training Loss: 0.0000, Validation Loss: 0.0042
# Epoch 257/2000, Training Loss: 0.0000, Validation Loss: 0.0042
# Epoch 258/2000, Training Loss: 0.0000, Validation Loss: 0.0042
# Epoch 259/2000, Training Loss: 0.0000, Validation Loss: 0.0042
# Epoch 260/2000, Training Loss: 0.0000, Validation Loss: 0.0042
# Epoch 261/2000, Training Loss: 0.0000, Validation Loss: 0.0042
# Epoch 262/2000, Training Loss: 0.0000, Validation Loss: 0.0042
# Epoch 263/2000, Training Loss: 0.0000, Validation Loss: 0.0042
# Epoch 264/2000, Training Loss: 0.0000, Validation Loss: 0.0042
# Epoch 265/2000, Training Loss: 0.0000, Validation Loss: 0.0042
# Epoch 266/2000, Training Loss: 0.0000, Validation Loss: 0.0042
# Epoch 267/2000, Training Loss: 0.0000, Validation Loss: 0.0042
# Epoch 268/2000, Training Loss: 0.0000, Validation Loss: 0.0041
# Epoch 269/2000, Training Loss: 0.0000, Validation Loss: 0.0041
# Epoch 270/2000, Training Loss: 0.0000, Validation Loss: 0.0041
# Epoch 271/2000, Training Loss: 0.0000, Validation Loss: 0.0041
# Epoch 272/2000, Training Loss: 0.0000, Validation Loss: 0.0041
# Epoch 273/2000, Training Loss: 0.0000, Validation Loss: 0.0041
# Epoch 274/2000, Training Loss: 0.0000, Validation Loss: 0.0041
# Epoch 275/2000, Training Loss: 0.0000, Validation Loss: 0.0041
# Epoch 276/2000, Training Loss: 0.0000, Validation Loss: 0.0041
# Epoch 277/2000, Training Loss: 0.0000, Validation Loss: 0.0041
# Epoch 278/2000, Training Loss: 0.0000, Validation Loss: 0.0041
# Epoch 279/2000, Training Loss: 0.0000, Validation Loss: 0.0041
# Epoch 280/2000, Training Loss: 0.0000, Validation Loss: 0.0041
# Epoch 281/2000, Training Loss: 0.0000, Validation Loss: 0.0041
# Epoch 282/2000, Training Loss: 0.0000, Validation Loss: 0.0040
# Epoch 283/2000, Training Loss: 0.0000, Validation Loss: 0.0040
# Epoch 284/2000, Training Loss: 0.0000, Validation Loss: 0.0040
# Epoch 285/2000, Training Loss: 0.0000, Validation Loss: 0.0040
# Epoch 286/2000, Training Loss: 0.0000, Validation Loss: 0.0040
# Epoch 287/2000, Training Loss: 0.0000, Validation Loss: 0.0040
# Epoch 288/2000, Training Loss: 0.0000, Validation Loss: 0.0040
# Epoch 289/2000, Training Loss: 0.0000, Validation Loss: 0.0040
# Epoch 290/2000, Training Loss: 0.0000, Validation Loss: 0.0040
# Epoch 291/2000, Training Loss: 0.0000, Validation Loss: 0.0040
# Epoch 292/2000, Training Loss: 0.0000, Validation Loss: 0.0040
# Epoch 293/2000, Training Loss: 0.0000, Validation Loss: 0.0040
# Epoch 294/2000, Training Loss: 0.0000, Validation Loss: 0.0040
# Epoch 295/2000, Training Loss: 0.0000, Validation Loss: 0.0040
# Epoch 296/2000, Training Loss: 0.0000, Validation Loss: 0.0040
# Epoch 297/2000, Training Loss: 0.0000, Validation Loss: 0.0040
# Epoch 298/2000, Training Loss: 0.0000, Validation Loss: 0.0039
# Epoch 299/2000, Training Loss: 0.0000, Validation Loss: 0.0039
# Epoch 300/2000, Training Loss: 0.0000, Validation Loss: 0.0039
# Epoch 301/2000, Training Loss: 0.0000, Validation Loss: 0.0039
# Epoch 302/2000, Training Loss: 0.0000, Validation Loss: 0.0039
# Epoch 303/2000, Training Loss: 0.0000, Validation Loss: 0.0039
# Epoch 304/2000, Training Loss: 0.0000, Validation Loss: 0.0039
# Epoch 305/2000, Training Loss: 0.0000, Validation Loss: 0.0039
# Epoch 306/2000, Training Loss: 0.0000, Validation Loss: 0.0039
# Epoch 307/2000, Training Loss: 0.0000, Validation Loss: 0.0039
# Epoch 308/2000, Training Loss: 0.0000, Validation Loss: 0.0039
# Epoch 309/2000, Training Loss: 0.0000, Validation Loss: 0.0039
# Epoch 310/2000, Training Loss: 0.0000, Validation Loss: 0.0039
# Epoch 311/2000, Training Loss: 0.0000, Validation Loss: 0.0039
# Epoch 312/2000, Training Loss: 0.0000, Validation Loss: 0.0039
# Epoch 313/2000, Training Loss: 0.0000, Validation Loss: 0.0039
# Epoch 314/2000, Training Loss: 0.0000, Validation Loss: 0.0038
# Epoch 315/2000, Training Loss: 0.0000, Validation Loss: 0.0038
# Epoch 316/2000, Training Loss: 0.0000, Validation Loss: 0.0038
# Epoch 317/2000, Training Loss: 0.0000, Validation Loss: 0.0038
# Epoch 318/2000, Training Loss: 0.0000, Validation Loss: 0.0038
# Epoch 319/2000, Training Loss: 0.0000, Validation Loss: 0.0038
# Epoch 320/2000, Training Loss: 0.0000, Validation Loss: 0.0038
# Epoch 321/2000, Training Loss: 0.0000, Validation Loss: 0.0038
# Epoch 322/2000, Training Loss: 0.0000, Validation Loss: 0.0038
# Epoch 323/2000, Training Loss: 0.0000, Validation Loss: 0.0038
# Epoch 324/2000, Training Loss: 0.0000, Validation Loss: 0.0038
# Epoch 325/2000, Training Loss: 0.0000, Validation Loss: 0.0038
# Epoch 326/2000, Training Loss: 0.0000, Validation Loss: 0.0038
# Epoch 327/2000, Training Loss: 0.0000, Validation Loss: 0.0038
# Epoch 328/2000, Training Loss: 0.0000, Validation Loss: 0.0038
# Epoch 329/2000, Training Loss: 0.0000, Validation Loss: 0.0038
# Epoch 330/2000, Training Loss: 0.0000, Validation Loss: 0.0038
# Epoch 331/2000, Training Loss: 0.0000, Validation Loss: 0.0038
# Epoch 332/2000, Training Loss: 0.0000, Validation Loss: 0.0037
# Epoch 333/2000, Training Loss: 0.0000, Validation Loss: 0.0037
# Epoch 334/2000, Training Loss: 0.0000, Validation Loss: 0.0037
# Epoch 335/2000, Training Loss: 0.0000, Validation Loss: 0.0037
# Epoch 336/2000, Training Loss: 0.0000, Validation Loss: 0.0037
# Epoch 337/2000, Training Loss: 0.0000, Validation Loss: 0.0037
# Epoch 338/2000, Training Loss: 0.0000, Validation Loss: 0.0037
# Epoch 339/2000, Training Loss: 0.0000, Validation Loss: 0.0037
# Epoch 340/2000, Training Loss: 0.0000, Validation Loss: 0.0037
# Epoch 341/2000, Training Loss: 0.0000, Validation Loss: 0.0037
# Epoch 342/2000, Training Loss: 0.0000, Validation Loss: 0.0037
# Epoch 343/2000, Training Loss: 0.0000, Validation Loss: 0.0037
# Epoch 344/2000, Training Loss: 0.0000, Validation Loss: 0.0037
# Epoch 345/2000, Training Loss: 0.0000, Validation Loss: 0.0037
# Epoch 346/2000, Training Loss: 0.0000, Validation Loss: 0.0037
# Epoch 347/2000, Training Loss: 0.0000, Validation Loss: 0.0037
# Epoch 348/2000, Training Loss: 0.0000, Validation Loss: 0.0037
# Epoch 349/2000, Training Loss: 0.0000, Validation Loss: 0.0037
# Epoch 350/2000, Training Loss: 0.0000, Validation Loss: 0.0037
# Epoch 351/2000, Training Loss: 0.0000, Validation Loss: 0.0036
# Epoch 352/2000, Training Loss: 0.0000, Validation Loss: 0.0036
# Epoch 353/2000, Training Loss: 0.0000, Validation Loss: 0.0036
# Epoch 354/2000, Training Loss: 0.0000, Validation Loss: 0.0036
# Epoch 355/2000, Training Loss: 0.0000, Validation Loss: 0.0036
# Epoch 356/2000, Training Loss: 0.0000, Validation Loss: 0.0036
# Epoch 357/2000, Training Loss: 0.0000, Validation Loss: 0.0036
# Epoch 358/2000, Training Loss: 0.0000, Validation Loss: 0.0036
# Epoch 359/2000, Training Loss: 0.0000, Validation Loss: 0.0036
# Epoch 360/2000, Training Loss: 0.0000, Validation Loss: 0.0036
# Epoch 361/2000, Training Loss: 0.0000, Validation Loss: 0.0036
# Epoch 362/2000, Training Loss: 0.0000, Validation Loss: 0.0036
# Epoch 363/2000, Training Loss: 0.0000, Validation Loss: 0.0036
# Epoch 364/2000, Training Loss: 0.0000, Validation Loss: 0.0036
# Epoch 365/2000, Training Loss: 0.0000, Validation Loss: 0.0036
# Epoch 366/2000, Training Loss: 0.0000, Validation Loss: 0.0036
# Epoch 367/2000, Training Loss: 0.0000, Validation Loss: 0.0036
# Epoch 368/2000, Training Loss: 0.0000, Validation Loss: 0.0036
# Epoch 369/2000, Training Loss: 0.0000, Validation Loss: 0.0036
# Epoch 370/2000, Training Loss: 0.0000, Validation Loss: 0.0036
# Epoch 371/2000, Training Loss: 0.0000, Validation Loss: 0.0036
# Epoch 372/2000, Training Loss: 0.0000, Validation Loss: 0.0036
# Epoch 373/2000, Training Loss: 0.0000, Validation Loss: 0.0035
# Epoch 374/2000, Training Loss: 0.0000, Validation Loss: 0.0035
# Epoch 375/2000, Training Loss: 0.0000, Validation Loss: 0.0035
# Epoch 376/2000, Training Loss: 0.0000, Validation Loss: 0.0035
# Epoch 377/2000, Training Loss: 0.0000, Validation Loss: 0.0035
# Epoch 378/2000, Training Loss: 0.0000, Validation Loss: 0.0035
# Epoch 379/2000, Training Loss: 0.0000, Validation Loss: 0.0035
# Epoch 380/2000, Training Loss: 0.0000, Validation Loss: 0.0035
# Epoch 381/2000, Training Loss: 0.0000, Validation Loss: 0.0035
# Epoch 382/2000, Training Loss: 0.0000, Validation Loss: 0.0035
# Epoch 383/2000, Training Loss: 0.0000, Validation Loss: 0.0035
# Epoch 384/2000, Training Loss: 0.0000, Validation Loss: 0.0035
# Epoch 385/2000, Training Loss: 0.0000, Validation Loss: 0.0035
# Epoch 386/2000, Training Loss: 0.0000, Validation Loss: 0.0035
# Epoch 387/2000, Training Loss: 0.0000, Validation Loss: 0.0035
# Epoch 388/2000, Training Loss: 0.0000, Validation Loss: 0.0035
# Epoch 389/2000, Training Loss: 0.0000, Validation Loss: 0.0035
# Epoch 390/2000, Training Loss: 0.0000, Validation Loss: 0.0035
# Epoch 391/2000, Training Loss: 0.0000, Validation Loss: 0.0035
# Epoch 392/2000, Training Loss: 0.0000, Validation Loss: 0.0035
# Epoch 393/2000, Training Loss: 0.0000, Validation Loss: 0.0035
# Epoch 394/2000, Training Loss: 0.0000, Validation Loss: 0.0035
# Epoch 395/2000, Training Loss: 0.0000, Validation Loss: 0.0035
# Epoch 396/2000, Training Loss: 0.0000, Validation Loss: 0.0034
# Epoch 397/2000, Training Loss: 0.0000, Validation Loss: 0.0034
# Epoch 398/2000, Training Loss: 0.0000, Validation Loss: 0.0034
# Epoch 399/2000, Training Loss: 0.0000, Validation Loss: 0.0034
# Epoch 400/2000, Training Loss: 0.0000, Validation Loss: 0.0034
# Epoch 401/2000, Training Loss: 0.0000, Validation Loss: 0.0034
# Epoch 402/2000, Training Loss: 0.0000, Validation Loss: 0.0034
# Epoch 403/2000, Training Loss: 0.0000, Validation Loss: 0.0034
# Epoch 404/2000, Training Loss: 0.0000, Validation Loss: 0.0034
# Epoch 405/2000, Training Loss: 0.0000, Validation Loss: 0.0034
# Epoch 406/2000, Training Loss: 0.0000, Validation Loss: 0.0034
# Epoch 407/2000, Training Loss: 0.0000, Validation Loss: 0.0034
# Epoch 408/2000, Training Loss: 0.0000, Validation Loss: 0.0034
# Epoch 409/2000, Training Loss: 0.0000, Validation Loss: 0.0034
# Epoch 410/2000, Training Loss: 0.0000, Validation Loss: 0.0034
# Epoch 411/2000, Training Loss: 0.0000, Validation Loss: 0.0034
# Epoch 412/2000, Training Loss: 0.0000, Validation Loss: 0.0034
# Epoch 413/2000, Training Loss: 0.0000, Validation Loss: 0.0034
# Epoch 414/2000, Training Loss: 0.0000, Validation Loss: 0.0034
# Epoch 415/2000, Training Loss: 0.0000, Validation Loss: 0.0034
# Epoch 416/2000, Training Loss: 0.0000, Validation Loss: 0.0034
# Epoch 417/2000, Training Loss: 0.0000, Validation Loss: 0.0034
# Epoch 418/2000, Training Loss: 0.0000, Validation Loss: 0.0034
# Epoch 419/2000, Training Loss: 0.0000, Validation Loss: 0.0034
# Epoch 420/2000, Training Loss: 0.0000, Validation Loss: 0.0034
# Epoch 421/2000, Training Loss: 0.0000, Validation Loss: 0.0034
# Epoch 422/2000, Training Loss: 0.0000, Validation Loss: 0.0033
# Epoch 423/2000, Training Loss: 0.0000, Validation Loss: 0.0033
# Epoch 424/2000, Training Loss: 0.0000, Validation Loss: 0.0033
# Epoch 425/2000, Training Loss: 0.0000, Validation Loss: 0.0033
# Epoch 426/2000, Training Loss: 0.0000, Validation Loss: 0.0033
# Epoch 427/2000, Training Loss: 0.0000, Validation Loss: 0.0033
# Epoch 428/2000, Training Loss: 0.0000, Validation Loss: 0.0033
# Epoch 429/2000, Training Loss: 0.0000, Validation Loss: 0.0033
# Epoch 430/2000, Training Loss: 0.0000, Validation Loss: 0.0033
# Epoch 431/2000, Training Loss: 0.0000, Validation Loss: 0.0033
# Epoch 432/2000, Training Loss: 0.0000, Validation Loss: 0.0033
# Epoch 433/2000, Training Loss: 0.0000, Validation Loss: 0.0033
# Epoch 434/2000, Training Loss: 0.0000, Validation Loss: 0.0033
# Epoch 435/2000, Training Loss: 0.0000, Validation Loss: 0.0033
# Epoch 436/2000, Training Loss: 0.0000, Validation Loss: 0.0033
# Epoch 437/2000, Training Loss: 0.0000, Validation Loss: 0.0033
# Epoch 438/2000, Training Loss: 0.0000, Validation Loss: 0.0033
# Epoch 439/2000, Training Loss: 0.0000, Validation Loss: 0.0033
# Epoch 440/2000, Training Loss: 0.0000, Validation Loss: 0.0033
# Epoch 441/2000, Training Loss: 0.0000, Validation Loss: 0.0033
# Epoch 442/2000, Training Loss: 0.0000, Validation Loss: 0.0033
# Epoch 443/2000, Training Loss: 0.0000, Validation Loss: 0.0033
# Epoch 444/2000, Training Loss: 0.0000, Validation Loss: 0.0033
# Epoch 445/2000, Training Loss: 0.0000, Validation Loss: 0.0033
# Epoch 446/2000, Training Loss: 0.0000, Validation Loss: 0.0033
# Epoch 447/2000, Training Loss: 0.0000, Validation Loss: 0.0033
# Epoch 448/2000, Training Loss: 0.0000, Validation Loss: 0.0033
# Epoch 449/2000, Training Loss: 0.0000, Validation Loss: 0.0033
# Epoch 450/2000, Training Loss: 0.0000, Validation Loss: 0.0032
# Epoch 451/2000, Training Loss: 0.0000, Validation Loss: 0.0032
# Epoch 452/2000, Training Loss: 0.0000, Validation Loss: 0.0032
# Epoch 453/2000, Training Loss: 0.0000, Validation Loss: 0.0032
# Epoch 454/2000, Training Loss: 0.0000, Validation Loss: 0.0032
# Epoch 455/2000, Training Loss: 0.0000, Validation Loss: 0.0032
# Epoch 456/2000, Training Loss: 0.0000, Validation Loss: 0.0032
# Epoch 457/2000, Training Loss: 0.0000, Validation Loss: 0.0032
# Epoch 458/2000, Training Loss: 0.0000, Validation Loss: 0.0032
# Epoch 459/2000, Training Loss: 0.0000, Validation Loss: 0.0032
# Epoch 460/2000, Training Loss: 0.0000, Validation Loss: 0.0032
# Epoch 461/2000, Training Loss: 0.0000, Validation Loss: 0.0032
# Epoch 462/2000, Training Loss: 0.0000, Validation Loss: 0.0032
# Epoch 463/2000, Training Loss: 0.0000, Validation Loss: 0.0032
# Epoch 464/2000, Training Loss: 0.0000, Validation Loss: 0.0032
# Epoch 465/2000, Training Loss: 0.0000, Validation Loss: 0.0032
# Epoch 466/2000, Training Loss: 0.0000, Validation Loss: 0.0032
# Epoch 467/2000, Training Loss: 0.0000, Validation Loss: 0.0032
# Epoch 468/2000, Training Loss: 0.0000, Validation Loss: 0.0032
# Epoch 469/2000, Training Loss: 0.0000, Validation Loss: 0.0032
# Epoch 470/2000, Training Loss: 0.0000, Validation Loss: 0.0032
# Epoch 471/2000, Training Loss: 0.0000, Validation Loss: 0.0032
# Epoch 472/2000, Training Loss: 0.0000, Validation Loss: 0.0032
# Epoch 473/2000, Training Loss: 0.0000, Validation Loss: 0.0032
# Epoch 474/2000, Training Loss: 0.0000, Validation Loss: 0.0032
# Epoch 475/2000, Training Loss: 0.0000, Validation Loss: 0.0032
# Epoch 476/2000, Training Loss: 0.0000, Validation Loss: 0.0032
# Epoch 477/2000, Training Loss: 0.0000, Validation Loss: 0.0032
# Epoch 478/2000, Training Loss: 0.0000, Validation Loss: 0.0032
# Epoch 479/2000, Training Loss: 0.0000, Validation Loss: 0.0032
# Epoch 480/2000, Training Loss: 0.0000, Validation Loss: 0.0032
# Epoch 481/2000, Training Loss: 0.0000, Validation Loss: 0.0032
# Epoch 482/2000, Training Loss: 0.0000, Validation Loss: 0.0031
# Epoch 483/2000, Training Loss: 0.0000, Validation Loss: 0.0031
# Epoch 484/2000, Training Loss: 0.0000, Validation Loss: 0.0031
# Epoch 485/2000, Training Loss: 0.0000, Validation Loss: 0.0031
# Epoch 486/2000, Training Loss: 0.0000, Validation Loss: 0.0031
# Epoch 487/2000, Training Loss: 0.0000, Validation Loss: 0.0031
# Epoch 488/2000, Training Loss: 0.0000, Validation Loss: 0.0031
# Epoch 489/2000, Training Loss: 0.0000, Validation Loss: 0.0031
# Epoch 490/2000, Training Loss: 0.0000, Validation Loss: 0.0031
# Epoch 491/2000, Training Loss: 0.0000, Validation Loss: 0.0031
# Epoch 492/2000, Training Loss: 0.0000, Validation Loss: 0.0031
# Epoch 493/2000, Training Loss: 0.0000, Validation Loss: 0.0031
# Epoch 494/2000, Training Loss: 0.0000, Validation Loss: 0.0031
# Epoch 495/2000, Training Loss: 0.0000, Validation Loss: 0.0031
# Epoch 496/2000, Training Loss: 0.0000, Validation Loss: 0.0031
# Epoch 497/2000, Training Loss: 0.0000, Validation Loss: 0.0031
# Epoch 498/2000, Training Loss: 0.0000, Validation Loss: 0.0031
# Epoch 499/2000, Training Loss: 0.0000, Validation Loss: 0.0031
# Epoch 500/2000, Training Loss: 0.0000, Validation Loss: 0.0031
# Epoch 501/2000, Training Loss: 0.0000, Validation Loss: 0.0031
# Epoch 502/2000, Training Loss: 0.0000, Validation Loss: 0.0031
# Epoch 503/2000, Training Loss: 0.0000, Validation Loss: 0.0031
# Epoch 504/2000, Training Loss: 0.0000, Validation Loss: 0.0031
# Epoch 505/2000, Training Loss: 0.0000, Validation Loss: 0.0031
# Epoch 506/2000, Training Loss: 0.0000, Validation Loss: 0.0031
# Epoch 507/2000, Training Loss: 0.0000, Validation Loss: 0.0031
# Epoch 508/2000, Training Loss: 0.0000, Validation Loss: 0.0031
# Epoch 509/2000, Training Loss: 0.0000, Validation Loss: 0.0031
# Epoch 510/2000, Training Loss: 0.0000, Validation Loss: 0.0031
# Epoch 511/2000, Training Loss: 0.0000, Validation Loss: 0.0031
# Epoch 512/2000, Training Loss: 0.0000, Validation Loss: 0.0031
# Epoch 513/2000, Training Loss: 0.0000, Validation Loss: 0.0031
# Epoch 514/2000, Training Loss: 0.0000, Validation Loss: 0.0031
# Epoch 515/2000, Training Loss: 0.0000, Validation Loss: 0.0030
# Epoch 516/2000, Training Loss: 0.0000, Validation Loss: 0.0030
# Epoch 517/2000, Training Loss: 0.0000, Validation Loss: 0.0030
# Epoch 518/2000, Training Loss: 0.0000, Validation Loss: 0.0030
# Epoch 519/2000, Training Loss: 0.0000, Validation Loss: 0.0030
# Epoch 520/2000, Training Loss: 0.0000, Validation Loss: 0.0030
# Epoch 521/2000, Training Loss: 0.0000, Validation Loss: 0.0030
# Epoch 522/2000, Training Loss: 0.0000, Validation Loss: 0.0030
# Epoch 523/2000, Training Loss: 0.0000, Validation Loss: 0.0030
# Epoch 524/2000, Training Loss: 0.0000, Validation Loss: 0.0030
# Epoch 525/2000, Training Loss: 0.0000, Validation Loss: 0.0030
# Epoch 526/2000, Training Loss: 0.0000, Validation Loss: 0.0030
# Epoch 527/2000, Training Loss: 0.0000, Validation Loss: 0.0030
# Epoch 528/2000, Training Loss: 0.0000, Validation Loss: 0.0030
# Epoch 529/2000, Training Loss: 0.0000, Validation Loss: 0.0030
# Epoch 530/2000, Training Loss: 0.0000, Validation Loss: 0.0030
# Epoch 531/2000, Training Loss: 0.0000, Validation Loss: 0.0030
# Epoch 532/2000, Training Loss: 0.0000, Validation Loss: 0.0030
# Epoch 533/2000, Training Loss: 0.0000, Validation Loss: 0.0030
# Epoch 534/2000, Training Loss: 0.0000, Validation Loss: 0.0030
# Epoch 535/2000, Training Loss: 0.0000, Validation Loss: 0.0030
# Epoch 536/2000, Training Loss: 0.0000, Validation Loss: 0.0030
# Epoch 537/2000, Training Loss: 0.0000, Validation Loss: 0.0030
# Epoch 538/2000, Training Loss: 0.0000, Validation Loss: 0.0030
# Epoch 539/2000, Training Loss: 0.0000, Validation Loss: 0.0030
# Epoch 540/2000, Training Loss: 0.0000, Validation Loss: 0.0030
# Epoch 541/2000, Training Loss: 0.0000, Validation Loss: 0.0030
# Epoch 542/2000, Training Loss: 0.0000, Validation Loss: 0.0030
# Epoch 543/2000, Training Loss: 0.0000, Validation Loss: 0.0030
# Epoch 544/2000, Training Loss: 0.0000, Validation Loss: 0.0030
# Epoch 545/2000, Training Loss: 0.0000, Validation Loss: 0.0030
# Epoch 546/2000, Training Loss: 0.0000, Validation Loss: 0.0030
# Epoch 547/2000, Training Loss: 0.0000, Validation Loss: 0.0030
# Epoch 548/2000, Training Loss: 0.0000, Validation Loss: 0.0030
# Epoch 549/2000, Training Loss: 0.0000, Validation Loss: 0.0030
# Epoch 550/2000, Training Loss: 0.0000, Validation Loss: 0.0030
# Epoch 551/2000, Training Loss: 0.0000, Validation Loss: 0.0030
# Epoch 552/2000, Training Loss: 0.0000, Validation Loss: 0.0030
# Epoch 553/2000, Training Loss: 0.0000, Validation Loss: 0.0029
# Epoch 554/2000, Training Loss: 0.0000, Validation Loss: 0.0029
# Epoch 555/2000, Training Loss: 0.0000, Validation Loss: 0.0029
# Epoch 556/2000, Training Loss: 0.0000, Validation Loss: 0.0029
# Epoch 557/2000, Training Loss: 0.0000, Validation Loss: 0.0029
# Epoch 558/2000, Training Loss: 0.0000, Validation Loss: 0.0029
# Epoch 559/2000, Training Loss: 0.0000, Validation Loss: 0.0029
# Epoch 560/2000, Training Loss: 0.0000, Validation Loss: 0.0029
# Epoch 561/2000, Training Loss: 0.0000, Validation Loss: 0.0029
# Epoch 562/2000, Training Loss: 0.0000, Validation Loss: 0.0029
# Epoch 563/2000, Training Loss: 0.0000, Validation Loss: 0.0029
# Epoch 564/2000, Training Loss: 0.0000, Validation Loss: 0.0029
# Epoch 565/2000, Training Loss: 0.0000, Validation Loss: 0.0029
# Epoch 566/2000, Training Loss: 0.0000, Validation Loss: 0.0029
# Epoch 567/2000, Training Loss: 0.0000, Validation Loss: 0.0029
# Epoch 568/2000, Training Loss: 0.0000, Validation Loss: 0.0029
# Epoch 569/2000, Training Loss: 0.0000, Validation Loss: 0.0029
# Epoch 570/2000, Training Loss: 0.0000, Validation Loss: 0.0029
# Epoch 571/2000, Training Loss: 0.0000, Validation Loss: 0.0029
# Epoch 572/2000, Training Loss: 0.0000, Validation Loss: 0.0029
# Epoch 573/2000, Training Loss: 0.0000, Validation Loss: 0.0029
# Epoch 574/2000, Training Loss: 0.0000, Validation Loss: 0.0029
# Epoch 575/2000, Training Loss: 0.0000, Validation Loss: 0.0029
# Epoch 576/2000, Training Loss: 0.0000, Validation Loss: 0.0029
# Epoch 577/2000, Training Loss: 0.0000, Validation Loss: 0.0029
# Epoch 578/2000, Training Loss: 0.0000, Validation Loss: 0.0029
# Epoch 579/2000, Training Loss: 0.0000, Validation Loss: 0.0029
# Epoch 580/2000, Training Loss: 0.0000, Validation Loss: 0.0029
# Epoch 581/2000, Training Loss: 0.0000, Validation Loss: 0.0029
# Epoch 582/2000, Training Loss: 0.0000, Validation Loss: 0.0029
# Epoch 583/2000, Training Loss: 0.0000, Validation Loss: 0.0029
# Epoch 584/2000, Training Loss: 0.0000, Validation Loss: 0.0029
# Epoch 585/2000, Training Loss: 0.0000, Validation Loss: 0.0029
# Epoch 586/2000, Training Loss: 0.0000, Validation Loss: 0.0029
# Epoch 587/2000, Training Loss: 0.0000, Validation Loss: 0.0029
# Epoch 588/2000, Training Loss: 0.0000, Validation Loss: 0.0029
# Epoch 589/2000, Training Loss: 0.0000, Validation Loss: 0.0029
# Epoch 590/2000, Training Loss: 0.0000, Validation Loss: 0.0029
# Epoch 591/2000, Training Loss: 0.0000, Validation Loss: 0.0029
# Epoch 592/2000, Training Loss: 0.0000, Validation Loss: 0.0029
# Epoch 593/2000, Training Loss: 0.0000, Validation Loss: 0.0029
# Epoch 594/2000, Training Loss: 0.0000, Validation Loss: 0.0029
# Epoch 595/2000, Training Loss: 0.0000, Validation Loss: 0.0028
# Epoch 596/2000, Training Loss: 0.0000, Validation Loss: 0.0028
# Epoch 597/2000, Training Loss: 0.0000, Validation Loss: 0.0028
# Epoch 598/2000, Training Loss: 0.0000, Validation Loss: 0.0028
# Epoch 599/2000, Training Loss: 0.0000, Validation Loss: 0.0028

# %% [markdown]
# model.to(device): Moves the model to the specified device (CPU or GPU).
#
# criterion: Defines the loss function, in this case, CrossEntropyLoss, which is commonly used for multi-class classification problems.
#
# optimizer: Uses Stochastic Gradient Descent (SGD) to update model weights based on the gradients computed during backpropagation. Learning rate (lr) is set to 0.01.
#
# Loops over the dataset for a specified number of epochs (num_epochs=5).
#
# model.train(): Sets the model to training mode, enabling behaviors like dropout and batch normalization.
#
# running_train_loss: Keeps track of the cumulative training loss for the current epoch.
#
# labels.view(-1): Ensures the labels are in the correct shape for loss calculation.
#
# images.to(device), labels.to(device): Moves the data to the same device as the model.
#
# optimizer.zero_grad(): Resets gradients from the previous iteration.
#
# model(images): Forward pass - outputs predictions for the batch of images.
#
# criterion(output, labels): Calculates the loss between predictions (output) and true labels (labels).
#
# loss.backward(): Backpropagates the loss to compute gradients.
#
# optimizer.step(): Updates the model parameters using the computed gradients.
# running_train_loss: Accumulates the total training loss for the epoch.
#
# model.eval(): Sets the model to evaluation mode, disabling behaviors like dropout.
#
# torch.no_grad(): Disables gradient
# computation to save memory and improve performance during validation.
#
# Loops through the validation dataset and calculates the validation loss
#
# Computes the average loss for both training and validation datasets for the current epoch.
# Tracks the losses in train_losses and val_losses lists for later visualization.
# Prints the losses for each epoch.
#
# Plots the training and validation losses over the epochs to visualize the model's learning process.
# Key Indicators:
# Decreasing training loss: The model is learning.
# If validation loss decreases in tandem, the model generalizes well.
# If validation loss increases while training loss decreases, overfitting might be occurring.
#
# Saves the trained model's parameters (weights) to a file.
# The model can later be reloaded for evaluation or further training using:

# %%
loaded_model = copy.deepcopy(model).to(device)
loaded_model.load_state_dict(torch.load("TB_resnet.pth", weights_only=True))
loaded_model.eval()
print("Model loaded from TB_resnet.pth")

# Evaluate on test set
all_preds = []
all_labels = []

with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.squeeze().to(device)
        output = loaded_model(images)
        _, preds = torch.max(output, 1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

# Classification report
report = classification_report(all_labels, all_preds, target_names=[str(i) for i in range(num_classes)])
print("Classification Report:\n")
print(report)

# %% [markdown]
# No Gradient Calculation: torch.no_grad() ensures no gradients are calculated, saving memory and speeding up inference.
# Data Iteration: The test dataset (test_loader) is iterated batch by batch.
# Predictions:
# output contains the model's raw predictions (logits) for each class.
# torch.max(output, 1) gives the class index (preds) with the highest predicted probability for each sample in the batch.
# The predictions (preds) and ground truth (labels) are stored in lists for further evaluation.A deep copy of the existing model is created and moved to the appropriate device (CPU or GPU).
# The pre-trained model's state is loaded from the saved .pth file (bloodmnist_resnet.pth).
# The eval() method is called, putting the model in evaluation mode, which:
# Disables dropout layers (if any).
# Ensures batch normalization layers use pre-computed statistics.
#
# Classification Report:
# classification_report (from sklearn.metrics) calculates metrics like precision, recall, F1-score, and support for each class.
# The target_names argument maps class indices to their labels (or names). Here, it uses string representations of class indices (0, 1, 2, etc.).
#
# Precision: Fraction of true positive predictions out of all positive predictions for each class.
# Recall: Fraction of true positive predictions out of all actual positives for each class.
# F1-score: Harmonic mean of precision and recall.
# Support: Number of samples for each class in the test dataset.
